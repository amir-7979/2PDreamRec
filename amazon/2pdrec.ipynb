# %%
import pandas as pd

# Load the .df (Pickle) file
df = pd.read_pickle("data/train_fold1.df")  # or "data/train_fold1.df" if you're using folds

# Show the first 5 rows
print(df.head())  # or simply:

# For the first 10 rows
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 import pandas as pd
#       3 # Load the .df (Pickle) file
# ----> 4 df = pd.read_pickle("data/train.df")  # or "data/train_fold1.df" if you're using folds
#       6 # Show the first 5 rows
#       7 print(df.head())  # or simply:
#
# File ~/Desktop/.venv/lib/python3.12/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)
#     182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
# ...

# %%
# !python3 movie.py
# Out:
# Mapping file not found. Proceeding without genre filtering.
# Genre mapping JSON file not found
#
# ========== Fold 1 ==========
# 3883
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [44,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [44,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [44,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [44,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# /pytorch/aten/src/ATen/native/cuda/Indexing.cu:1422: indexSelectLargeIndex: block: [44,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ...
